# %% [markdown]
# # Image Ploting

# %%
# %matplotlib inline

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.asarray(Image.open('images/rabbit.jpg'))
print(repr(img))
# Out:
# array([[  0,   0,   0, ...,  84,  84,  66],
#        [  0,   0,   0, ...,  89, 219,  84],
#        [  0,   0,   0, ...,  84,  84,  66],
#        ...,
#        [ 94,  84,  73, ..., 131, 136,  74],
#        [ 84,  94,  94, ...,  85, 148,  85],
#        [ 94,  73,  94, ..., 140, 114, 148]], dtype=uint8)

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 lum_img = img[:, :, 0]
#       2 plt.imshow(lum_img)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %%
plt.imshow(img, cmap='hot')

# %%
imgplot = plt.imshow(img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(img)
plt.colorbar()

# %%
plt.hist(img.ravel(), bins=range(256), fc='k', ec='k')
plt.show()

# %%
plt.imshow(img, clim=(0, 175))

# %%
imgplot = plt.imshow(img)
imgplot.set_clim(0, 175)

# %%
img = Image.open('images/rabbit.jpg')
img.thumbnail((64, 64))  # resizes image in-place
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(img, interpolation="bicubic")
