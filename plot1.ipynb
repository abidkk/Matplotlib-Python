# %% [markdown]
# # Matplotlib

# %% [markdown]
# - Plot 1 : simple plot

# %%
import matplotlib.pyplot as plt
x = ["Javascript", "Python", "Java", "C++"]
y = [70, 97, 50, 27]
plt.title("Programming Languages Sats 2024")
plt.bar(x,y)
plt.show()
