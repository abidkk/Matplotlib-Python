# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt

# Data
x = ["Python", "Java", "C++", "Javascript", "Php"]
y = [40, 10, 15, 30, 5]

# Create pie chart with labels
plt.pie(y, labels=x, autopct='%1.1f%%')  # Display percentages
plt.show()
