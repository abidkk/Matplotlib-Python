# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt

# %%
x = ['Mon', "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
y = [5,6,2,8,10,7,3]
plt.scatter(x,y)
plt.title("Scatter Plot", fontsize=20)
plt.xlabel("Day")
plt.ylabel("Range")

plt.show()
